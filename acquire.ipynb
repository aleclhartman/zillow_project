# %%
import numpy as np
import pandas as pd

import env

# %%
properties_query = """
SELECT id, parcelid, bathroomcnt, bedroomcnt, calculatedfinishedsquarefeet, fips, unitcnt, taxvaluedollarcnt, taxamount, (taxamount/taxvaluedollarcnt) as tax_rate
FROM properties_2017
WHERE unitcnt = 1;
"""

# %%
url = env.get_db_url("zillow")

# %%
properties = pd.read_sql(properties_query, url)
properties
# Out:
#               id  parcelid  bathroomcnt  bedroomcnt  \
# 0              4  10879947          0.0         0.0
# 1             10  11070347          4.0         4.0
# 2             20  11324547          2.0         4.0
# 3             21  11391347          0.0         0.0
# 4             22  11395747          0.0         0.0
# ...          ...       ...          ...         ...
# 1783868  2982265  13027311          4.0         4.0
# 1783869  2982280  11366340          1.0         2.0
# 1783870  2982281  13010327          3.0         3.0
# 1783871  2982282  12385768          4.0         4.0
# 1783872  2982283  11795063          1.0         1.0
#
#          calculatedfinishedsquarefeet    fips  unitcnt  taxvaluedollarcnt  \
# 0                              1776.0  6037.0      1.0           440101.0
# 1                              3095.0  6037.0      1.0           192544.0
# 2                              3633.0  6037.0      1.0           296425.0
# 3                              4053.0  6037.0      1.0           511433.0
# 4                              1442.0  6037.0      1.0            50689.0
# ...                               ...     ...      ...                ...
# 1783868                        4375.0  6037.0      1.0           422400.0
# 1783869                         798.0  6037.0      1.0           469300.0
# 1783870                        1526.0  6037.0      1.0           594022.0
# 1783871                        2110.0  6037.0      1.0           554009.0
# 1783872                        1040.0  6037.0      1.0           620284.0
#
#          taxamount  tax_rate
# 0          5725.17  0.013009
# 1          2460.72  0.012780
# 2          6941.39  0.023417
# 3          6840.34  0.013375
# 4          1522.08  0.030028
# ...            ...       ...
# 1783868   13877.56  0.032854
# 1783869    5764.45  0.012283
# 1783870    7343.47  0.012362
# 1783871    6761.20  0.012204
# 1783872    7611.91  0.012272
#
# [1783873 rows x 10 columns]

# %%
properties["id"].value_counts().max()
# Out:
# 1

# %%
properties.parcelid.value_counts().max()
# Out:
# 1

# %%
predictions_query = """
SELECT parcelid, MAX(transactiondate) as last_transaction_date
FROM predictions_2017
WHERE transactiondate >= "2017-05-01"
AND transactiondate <= "2017-06-30"
GROUP BY parcelid
ORDER BY last_transaction_date;
"""

# %%
predictions = pd.read_sql(predictions_query, url)
predictions
# Out:
#        parcelid last_transaction_date
# 0      13909504            2017-05-01
# 1      17172225            2017-05-01
# 2      12252417            2017-05-01
# 3      12529922            2017-05-01
# 4      12319747            2017-05-01
# ...         ...                   ...
# 21929  12321535            2017-06-30
# 21930  12070399            2017-06-30
# 21931  10975999            2017-06-30
# 21932  14647039            2017-06-30
# 21933  14451711            2017-06-30
#
# [21934 rows x 2 columns]

# %%
predictions.parcelid.value_counts().max()
# Out:
# 1

# %%
joined_query = """
SELECT prop.id, prop.parcelid, prop.bathroomcnt, prop.bedroomcnt, prop.calculatedfinishedsquarefeet, prop.fips, prop.unitcnt, prop.taxvaluedollarcnt, prop.taxamount, (prop.taxamount/prop.taxvaluedollarcnt) as taxrate, pred.transactiondate
FROM properties_2017 as prop
JOIN predictions_2017 as pred USING(parcelid)
WHERE prop.unitcnt = 1
AND pred.transactiondate >= "2017-05-01"
AND pred.transactiondate <= "2017-06-30"
ORDER BY pred.transactiondate;
"""

# %%
joined = pd.read_sql(joined_query, url)
joined
# Out:
#             id  parcelid  bathroomcnt  bedroomcnt  \
# 0       733483  11056104          3.0         3.0
# 1      1629778  11503172          3.0         4.0
# 2       438499  11993956          2.0         3.0
# 3      1956514  11054736          2.0         4.0
# 4       838335  11206210          2.0         2.0
# ...        ...       ...          ...         ...
# 13304  1664929  12832732          3.0         3.0
# 13305  1948691  12945108          2.0         3.0
# 13306  1480299  11464823          3.0         4.0
# 13307  1092708  11534364          2.0         3.0
# 13308  2678821  12942897          3.0         4.0
#
#        calculatedfinishedsquarefeet    fips  unitcnt  taxvaluedollarcnt  \
# 0                            1572.0  6037.0      1.0           404060.0
# 1                            3041.0  6037.0      1.0           245311.0
# 2                            1692.0  6037.0      1.0           649169.0
# 3                            1611.0  6037.0      1.0            89640.0
# 4                            1078.0  6037.0      1.0           124006.0
# ...                             ...     ...      ...                ...
# 13304                        1740.0  6037.0      1.0           436000.0
# 13305                        1536.0  6037.0      1.0           297097.0
# 13306                        2305.0  6037.0      1.0           579047.0
# 13307                        1997.0  6037.0      1.0           630933.0
# 13308                        1840.0  6037.0      1.0           337683.0
#
#        taxamount   taxrate transactiondate
# 0        4934.43  0.012212      2017-05-01
# 1        2963.65  0.012081      2017-05-01
# 2        8063.11  0.012421      2017-05-01
# 3        1144.73  0.012770      2017-05-01
# 4        2290.48  0.018471      2017-05-01
# ...          ...       ...             ...
# 13304    5192.45  0.011909      2017-06-30
# 13305    3519.78  0.011847      2017-06-30
# 13306    6996.21  0.012082      2017-06-30
# 13307    7587.79  0.012026      2017-06-30
# 13308    3893.77  0.011531      2017-06-30
#
# [13309 rows x 11 columns]

# %%
joined.parcelid.value_counts()
# Out:
# 13067305    2
# 11175935    1
# 12583749    1
# 12958562    1
# 12641113    1
#            ..
# 12901697    1
# 12506432    1
# 11251007    1
# 13073306    1
# 10717185    1
# Name: parcelid, Length: 13308, dtype: int64

# %%
joined.fips.value_counts()
# Out:
# 6037.0    13307
# 6059.0        2
# Name: fips, dtype: int64

# %%
joined[joined.parcelid == 13067305]
# Out:
#            id  parcelid  bathroomcnt  bedroomcnt  \
# 1234   159239  13067305          3.0         2.0
# 11354  159239  13067305          3.0         2.0
#
#        calculatedfinishedsquarefeet    fips  unitcnt  taxvaluedollarcnt  \
# 1234                         1149.0  6037.0      1.0           218619.0
# 11354                        1149.0  6037.0      1.0           218619.0
#
#        taxamount   taxrate transactiondate
# 1234     3074.84  0.014065      2017-05-05
# 11354    3074.84  0.014065      2017-06-26

# %%
joined.drop(index=1234, inplace=True)

# %%
joined
# Out:
#             id  parcelid  bathroomcnt  bedroomcnt  \
# 0       733483  11056104          3.0         3.0
# 1      1629778  11503172          3.0         4.0
# 2       438499  11993956          2.0         3.0
# 3      1956514  11054736          2.0         4.0
# 4       838335  11206210          2.0         2.0
# ...        ...       ...          ...         ...
# 13304  1664929  12832732          3.0         3.0
# 13305  1948691  12945108          2.0         3.0
# 13306  1480299  11464823          3.0         4.0
# 13307  1092708  11534364          2.0         3.0
# 13308  2678821  12942897          3.0         4.0
#
#        calculatedfinishedsquarefeet    fips  unitcnt  taxvaluedollarcnt  \
# 0                            1572.0  6037.0      1.0           404060.0
# 1                            3041.0  6037.0      1.0           245311.0
# 2                            1692.0  6037.0      1.0           649169.0
# 3                            1611.0  6037.0      1.0            89640.0
# 4                            1078.0  6037.0      1.0           124006.0
# ...                             ...     ...      ...                ...
# 13304                        1740.0  6037.0      1.0           436000.0
# 13305                        1536.0  6037.0      1.0           297097.0
# 13306                        2305.0  6037.0      1.0           579047.0
# 13307                        1997.0  6037.0      1.0           630933.0
# 13308                        1840.0  6037.0      1.0           337683.0
#
#        taxamount   taxrate transactiondate
# 0        4934.43  0.012212      2017-05-01
# 1        2963.65  0.012081      2017-05-01
# 2        8063.11  0.012421      2017-05-01
# 3        1144.73  0.012770      2017-05-01
# 4        2290.48  0.018471      2017-05-01
# ...          ...       ...             ...
# 13304    5192.45  0.011909      2017-06-30
# 13305    3519.78  0.011847      2017-06-30
# 13306    6996.21  0.012082      2017-06-30
# 13307    7587.79  0.012026      2017-06-30
# 13308    3893.77  0.011531      2017-06-30
#
# [13308 rows x 11 columns]

# %%
joined[joined.parcelid == 13067305]
# Out:
#            id  parcelid  bathroomcnt  bedroomcnt  \
# 11354  159239  13067305          3.0         2.0
#
#        calculatedfinishedsquarefeet    fips  unitcnt  taxvaluedollarcnt  \
# 11354                        1149.0  6037.0      1.0           218619.0
#
#        taxamount   taxrate transactiondate
# 11354    3074.84  0.014065      2017-06-26

# %%
joined.parcelid.value_counts().max()
# Out:
# 1

# %%
california_fips = pd.read_csv("california_fips.csv")
california_fips.drop(columns="Unnamed: 0", inplace=True)
california_fips
# Out:
#     06000              California
# 0    6001          Alameda County
# 1    6003           Alpine County
# 2    6005           Amador County
# 3    6007            Butte County
# 4    6009        Calaveras County
# 5    6011           Colusa County
# 6    6013     Contra Costa County
# 7    6015        Del Norte County
# 8    6017        El Dorado County
# 9    6019           Fresno County
# 10   6021            Glenn County
# 11   6023         Humboldt County
# 12   6025         Imperial County
# 13   6027             Inyo County
# 14   6029             Kern County
# 15   6031            Kings County
# 16   6033             Lake County
# 17   6035           Lassen County
# 18   6037      Los Angeles County
# 19   6039           Madera County
# 20   6041            Marin County
# 21   6043         Mariposa County
# 22   6045        Mendocino County
# 23   6047           Merced County
# 24   6049            Modoc County
# 25   6051             Mono County
# 26   6053         Monterey County
# 27   6055             Napa County
# 28   6057           Nevada County
# 29   6059           Orange County
# 30   6061           Placer County
# 31   6063           Plumas County
# 32   6065        Riverside County
# 33   6067       Sacramento County
# 34   6069       San Benito County
# 35   6071   San Bernardino County
# 36   6073        San Diego County
# 37   6075    San Francisco County
# 38   6077      San Joaquin County
# 39   6079  San Luis Obispo County
# 40   6081        San Mateo County
# 41   6083    Santa Barbara County
# 42   6085      Santa Clara County
# 43   6087       Santa Cruz County
# 44   6089           Shasta County
# 45   6091           Sierra County
# 46   6093         Siskiyou County
# 47   6095           Solano County
# 48   6097           Sonoma County
# 49   6099       Stanislaus County
# 50   6101           Sutter County
# 51   6103           Tehama County
# 52   6105          Trinity County
# 53   6107           Tulare County
# 54   6109         Tuolumne County
# 55   6111          Ventura County
# 56   6113             Yolo County
# 57   6115             Yuba County

# %%
alternate_joined_query = """SELECT prop.id, prop.parcelid, prop.bathroomcnt, prop.bedroomcnt, prop.calculatedfinishedsquarefeet, prop.fips, plut.propertylandusedesc, prop.unitcnt, prop.taxvaluedollarcnt, prop.taxamount, (prop.taxamount/prop.taxvaluedollarcnt) as tax_rate, pred.transactiondate
FROM properties_2017 as prop
JOIN predictions_2017 as pred USING(parcelid)
JOIN propertylandusetype as plut USING(propertylandusetypeid)
WHERE plut.propertylandusedesc = "Single Family Residential"
AND pred.transactiondate >= "2017-05-01"
AND pred.transactiondate <= "2017-06-30"
ORDER BY pred.transactiondate;
"""

# %%
alt_joined = pd.read_sql(alternate_joined_query, url)
alt_joined
# Out:
#             id  parcelid  bathroomcnt  bedroomcnt  \
# 0      1175489  14365030          2.5         3.0
# 1       733483  11056104          3.0         3.0
# 2      1629778  11503172          3.0         4.0
# 3       438499  11993956          2.0         3.0
# 4      1956514  11054736          2.0         4.0
# ...        ...       ...          ...         ...
# 15031  1324679  14339902          3.0         5.0
# 15032  2963359  13940564          3.0         5.0
# 15033  1948691  12945108          2.0         3.0
# 15034   444575  14214719          3.0         5.0
# 15035  1480299  11464823          3.0         4.0
#
#        calculatedfinishedsquarefeet    fips        propertylandusedesc  \
# 0                            1653.0  6059.0  Single Family Residential
# 1                            1572.0  6037.0  Single Family Residential
# 2                            3041.0  6037.0  Single Family Residential
# 3                            1692.0  6037.0  Single Family Residential
# 4                            1611.0  6037.0  Single Family Residential
# ...                             ...     ...                        ...
# 15031                        2526.0  6059.0  Single Family Residential
# 15032                        2735.0  6059.0  Single Family Residential
# 15033                        1536.0  6037.0  Single Family Residential
# 15034                        2655.0  6059.0  Single Family Residential
# 15035                        2305.0  6037.0  Single Family Residential
#
#        unitcnt  taxvaluedollarcnt  taxamount  tax_rate transactiondate
# 0          NaN           605000.0    6185.28  0.010224      2017-05-01
# 1          1.0           404060.0    4934.43  0.012212      2017-05-01
# 2          1.0           245311.0    2963.65  0.012081      2017-05-01
# 3          1.0           649169.0    8063.11  0.012421      2017-05-01
# 4          1.0            89640.0    1144.73  0.012770      2017-05-01
# ...        ...                ...        ...       ...             ...
# 15031      NaN           458903.0    5718.72  0.012462      2017-06-30
# 15032      NaN           115387.0    1465.88  0.012704      2017-06-30
# 15033      1.0           297097.0    3519.78  0.011847      2017-06-30
# 15034      NaN           746963.0    8065.50  0.010798      2017-06-30
# 15035      1.0           579047.0    6996.21  0.012082      2017-06-30
#
# [15036 rows x 12 columns]

# %%
alt_joined.fips.value_counts()
# Out:
# 6037.0    9630
# 6059.0    4109
# 6111.0    1297
# Name: fips, dtype: int64

# %%
alt_joined.unitcnt.value_counts()
# Out:
# 1.0    9593
# 2.0      10
# Name: unitcnt, dtype: int64

# %%
alt_joined.propertylandusedesc.value_counts()
# Out:
# Single Family Residential    15036
# Name: propertylandusedesc, dtype: int64
